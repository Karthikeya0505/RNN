# %%
from keras import Sequential
from keras.layers import Dense,SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 3)                 27
#
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## input_shape=(4,5)
# - here
#        4 - maximum time stamps(no.of words)
#        5 - vector size(based on vocabulary)

# %%
#from input layer to hidden layer
print(model.get_weights()[0].shape)
model.get_weights()[0]
# Out:
# (5, 3)
# array([[-0.56356   ,  0.17419523, -0.06510991],
#        [-0.6410298 , -0.20014781,  0.38044602],
#        [-0.6916896 ,  0.61401683,  0.6635441 ],
#        [-0.524367  ,  0.33299047,  0.5592219 ],
#        [ 0.7649415 , -0.7062144 ,  0.35730666]], dtype=float32)

# %%
#weights which are send back
print(model.get_weights()[1].shape)
model.get_weights()[1]
# Out:
# (3, 3)
# array([[-0.2510867 , -0.5145684 , -0.81986266],
#        [-0.12484124,  0.8571375 , -0.49972987],
#        [-0.95988023,  0.02312288,  0.27945524]], dtype=float32)

# %%
#biases of rnn nodes
print(model.get_weights()[2].shape)
model.get_weights()[2]
# Out:
# (3,)
# array([0., 0., 0.], dtype=float32)

# %%
print(model.get_weights()[3].shape)
model.get_weights()[3]
# Out:
# (3, 1)
# array([[-1.1638274 ],
#        [ 0.58693206],
#        [ 1.1018428 ]], dtype=float32)

# %%
#bias of output node
print(model.get_weights()[4].shape)
model.get_weights()[4]
# Out:
# (1,)
# array([0.], dtype=float32)
